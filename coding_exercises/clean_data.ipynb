# %%
import os 
import pandas as pd
import numpy as np

user = os.getenv("USERNAME")

path = (r"C:\Users\{}\OneDrive\Desktop".format(user))



dir = os.listdir(path)


for file in dir:
    if file.endswith("titanic_dataset.csv"):
        data_path = os.path.join(path,file)
        data = pd.read_csv(data_path)

data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 881          882         0       3                        Markun, Mr. Johann  \
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.columns = data.columns.str.lower()

# %%
import re

data.columns = data.columns.str.lower()

# %%
data["name"].str.replace(r'(\,(.*)\.)'," ")
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: name, Length: 891, dtype: object

# %%
test = data["name"].str.extract(r'\,(.\S*)')[0]

# %%
test_two = test.unique().tolist()

# %%
unique_values = test.unique().tolist()
title_values = "|".join(unique_values)

# %%
title_values
# Out:
# ' Mr.| Mrs.| Miss.| Master.| Don.| Rev.| Dr.| Mme.| Ms.| Major.| Lady.| Sir.| Mlle.| Col.| Capt.| the| Jonkheer.'

# %%
subset = data.value_counts(subset = ["pclass","cabin"])

# %%
data.groupby("pclass")["pclass"].apply(lambda x: (x <= 3).sum()).reset_index(name='count')
# Out:
#    pclass  count
# 0       1    216
# 1       2    184
# 2       3    491

# %%
subset_pclass = pd.DataFrame(data[(data["pclass"]==1)])
subset_pclass.sort_values(['fare'], ascending = True, inplace = True)

# %%
subset_pclass[["pclass","cabin","fare","age","sex"]].head()
# Out:
#      pclass cabin  fare   age   sex
# 822       1   NaN   0.0  38.0  male
# 633       1   NaN   0.0   NaN  male
# 263       1   B94   0.0  40.0  male
# 815       1  B102   0.0   NaN  male
# 806       1   A36   0.0  39.0  male

# %%
remove = ['cabin','ticket']
subset_pclass.drop(remove, inplace =True, axis =1)

# %%
subset_pclass.head()
# Out:
#      passengerid  survived  pclass                             name   sex
# 822          823         0       1  Reuchlin, Jonkheer. John George  male  \
# 633          634         0       1    Parr, Mr. William Henry Marsh  male
# 263          264         0       1            Harrison, Mr. William  male
# 815          816         0       1                 Fry, Mr. Richard  male
# 806          807         0       1           Andrews, Mr. Thomas Jr  male
#
#       age  sibsp  parch  fare embarked
# 822  38.0      0      0   0.0        S
# 633   NaN      0      0   0.0        S
# 263  40.0      0      0   0.0        S
# 815   NaN      0      0   0.0        S
# 806  39.0      0      0   0.0        S

# %%
np.sum(subset_pclass.isnull())
# Out:
# passengerid     0
# survived        0
# pclass          0
# name            0
# sex             0
# age            30
# sibsp           0
# parch           0
# fare            0
# embarked        2
# dtype: int64

# %%
subset_pclass.drop_duplicates()
# Out:
#      passengerid  survived  pclass                                name
# 822          823         0       1     Reuchlin, Jonkheer. John George  \
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 263          264         0       1               Harrison, Mr. William
# 815          816         0       1                    Fry, Mr. Richard
# 806          807         0       1              Andrews, Mr. Thomas Jr
# ..           ...       ...     ...                                 ...
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 438          439         0       1                   Fortune, Mr. Mark
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         sex   age  sibsp  parch      fare embarked
# 822    male  38.0      0      0    0.0000        S
# ...
