# %%
import mysql.connector
import pandas as pd
import glob
import numpy as np
import os
import csv
import yaml
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse


df2 = pd.read_csv('trend1.csv', parse_dates=['date'], index_col='date')

df2.drop(columns = ['business','Unnamed: 0'], inplace = True)

# %%
df2
# Out:
#             sales
# date
# 1992-01-01    790
# 1992-02-01    539
# 1992-03-01    535
# 1992-04-01    523
# 1992-05-01    552
# ...           ...
# 2020-10-01    455
# 2020-11-01    496
# 2020-12-01    900
# 2021-01-01    820
# 2021-02-01    458
#
# [350 rows x 1 columns]

# %%
result_mul = seasonal_decompose(df2['sales'], model='multiplicative', extrapolate_trend='freq')
plt.rcParams.update({'figure.figsize': (10,10)})
result_mul.plot().suptitle('Multiplicative Decompose', fontsize=22)
# Out:
# Text(0.5, 0.98, 'Multiplicative Decompose')
